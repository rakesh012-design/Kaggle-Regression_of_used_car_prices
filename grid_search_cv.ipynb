# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('train.csv')

# %%
test_data=pd.read_csv('test.csv')

# %%
numerical_features=['milage','model_year','price']

# %%
categorical_cols=['brand','model','fuel_type','transmission','int_col','accident','clean_title']

# %%
import re
def extract_horsepower(engine_str):
    match=re.search(r'(\d+\.?\d*)HP', engine_str)
    if match:
        return float(match.group(1))
    else:
        return None

# %%
data['horsepower']=data['engine'].apply(extract_horsepower)

# %%
test_data['horsepower']=data['engine'].apply(extract_horsepower)

# %%
data['fuel_type'].fillna('Gasoline',inplace=True)
data['accident'].fillna('None reported',inplace=True)
data['clean_title'].fillna('Yes',inplace=True)

# %%
data['horsepower'].fillna(data['horsepower'].median(),inplace=True)

# %%
test_data['fuel_type'].fillna('Gasoline',inplace=True)
test_data['accident'].fillna('None reported',inplace=True)
test_data['clean_title'].fillna('Yes',inplace=True)
test_data['horsepower'].fillna(data['horsepower'].median(),inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,StandardScaler,OrdinalEncoder,LabelEncoder
from sklearn.model_selection import GridSearchCV
x=data.drop(columns=['price','id','engine','clean_title'])
y=data['price']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_2=x.copy()
y_2=y.copy()
test_data_2=test_data.copy()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import xgboost as xgb

# %%
categoric_cols=['brand', 'model', 'fuel_type', 'transmission', 'ext_col', 'int_col', 'accident']
numeric_cols=['model_year', 'milage', 'horsepower']

# %%
le=LabelEncoder()

# %%
for i in categoric_cols:
    data[i]=le.fit_transform(data[i])
    test_data[i]=le.fit_transform(test_data[i])

# %%
preprocessor=ColumnTransformer(
    transformers=[
        ('numerical_features',StandardScaler(),numeric_cols),
    ]
)

# %%
model=xgb.XGBRegressor(max_depth=3,n_estimators=100)

# %%
model_pipeline=Pipeline(steps=[
    ('preprocessing',preprocessor),
    ('model',model)
])

# %%
data.drop(columns=['engine','id','clean_title']).corr()
# Out:
#                  brand     model  model_year    milage  fuel_type  \
# brand         1.000000 -0.040049   -0.014605 -0.007286   0.043534
# model        -0.040049  1.000000    0.001784  0.041706   0.009617
# model_year   -0.014605  0.001784    1.000000 -0.669936   0.010908
# milage       -0.007286  0.041706   -0.669936  1.000000  -0.105261
# fuel_type     0.043534  0.009617    0.010908 -0.105261   1.000000
# transmission  0.036984 -0.027031    0.043596 -0.041158   0.093713
# ext_col       0.006038  0.007560   -0.032189  0.027763  -0.010751
# int_col      -0.004765  0.076990    0.024833 -0.030846   0.004114
# accident      0.005564 -0.017556    0.256367 -0.321356   0.036566
# price         0.017657 -0.029865    0.231795 -0.283067   0.015427
# horsepower   -0.048659 -0.033289    0.351653 -0.388762  -0.013805
#
#               transmission   ext_col   int_col  accident     price  horsepower
# brand             0.036984  0.006038 -0.004765  0.005564  0.017657   -0.048659
# model            -0.027031  0.007560  0.076990 -0.017556 -0.029865   -0.033289
# model_year        0.043596 -0.032189  0.024833  0.256367  0.231795    0.351653
# milage           -0.041158  0.027763 -0.030846 -0.321356 -0.283067   -0.388762
# fuel_type         0.093713 -0.010751  0.004114  0.036566  0.015427   -0.013805
# transmission      1.000000  0.005435 -0.002534 -0.012481  0.014560    0.015964
# ext_col           0.005435  1.000000  0.067904 -0.020224 -0.017342   -0.033395
# int_col          -0.002534  0.067904  1.000000  0.000719  0.035174    0.018071
# accident         -0.012481 -0.020224  0.000719  1.000000  0.125122    0.183637
# price             0.014560 -0.017342  0.035174  0.125122  1.000000    0.207837
# horsepower        0.015964 -0.033395  0.018071  0.183637  0.207837    1.000000

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'model__n_estimators': [100, 200],
    "model__max_depth": [3, 5,7]
}

# %%
grid_search=GridSearchCV(
    estimator=model_pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1,
    verbose=2
)

# %%
y_train
# Out:
# 184031     24000
# 173831      8250
# 183819     30000
# 85525      45999
# 41872      42000
#            ...
# 119879     10000
# 103694     35900
# 131932     99750
# 146867      6730
# 121958    179900
# Name: price, Length: 150826, dtype: int64

# %%
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(transformers=[('numerical_features',
#                                                                          StandardScaler(),
#                                                                          ['model_year',
#                                                                           'milage',
#                                                                           'horsepower'])])),
#                                        ('model',
#                                         XGBRegressor(base_score=None,
#                                                      booster=None,
#                                                      callbacks=None,
#                                                      colsample_bylevel=None,
#                                                      colsample_bynode=None,
#                                                      colsample_bytree=None,
#                                                      device=None,
#                                                      early_stopping_rounds=None,
#                                                      enabl...
#                                                      max_cat_threshold=None,
#                                                      max_cat_to_onehot=None,
#                                                      max_delta_step=None,
#                                                      max_depth=3,
#                                                      max_leaves=None,
#                                                      min_child_weight=None,
#                                                      missing=nan,
#                                                      monotone_constraints=None,
#                                                      multi_strategy=None,
#                                                      n_estimators=100,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None, ...))]),
#              n_jobs=-1,
#              param_grid={'model__max_depth': [3, 5, 7],
#                          'model__n_estimators': [100, 200]},
#              scoring='neg_root_mean_squared_error', verbose=2)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best CV Score (RMSE):", -grid_search.best_score_)
print("Test Score (RMSE):", -grid_search.score(x_test, y_test))
# Out:
# Best Parameters: {'model__max_depth': 3, 'model__n_estimators': 100}
# Best CV Score (RMSE): 74805.821875
# Test Score (RMSE): 69321.0859375

# %%
test_data_final=test_data.drop(columns=['id','engine','clean_title'])
test_data_2_final=test_data_2.drop(columns=['id','engine','clean_title'])

# %%
model_pipeline.fit(x,y)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('numerical_features',
#                                                   StandardScaler(),
#                                                   ['model_year', 'milage',
#                                                    'horsepower'])])),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, device=None,
#                               early_stopping_rounds=None,
#                               enable_categorical=False, eval_met...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=3, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=100, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %%
test_data_pred=model_pipeline.predict(test_data_final)

# %%
submission_df_two=pd.DataFrame({
    'id':test_data['id'],
    'price':test_data_pred
})

# %%
submission_df_two.to_csv('submission_two.csv',index=False)

# %%
preprocessor_2=ColumnTransformer(
    transformers=[
        ('numeric_cols',StandardScaler(),numeric_cols),
        ('categroic_cols',OneHotEncoder(handle_unknown='ignore'),categoric_cols)
    ]
)

# %%
pipe_line_2=Pipeline(
    steps=[
        ('preprocessing_2',preprocessor_2),
        ('model',model)
    ]
)

# %%
pipe_line_2.fit(x_2,y_2)
# Out:
# Pipeline(steps=[('preprocessing_2',
#                  ColumnTransformer(transformers=[('numeric_cols',
#                                                   StandardScaler(),
#                                                   ['model_year', 'milage',
#                                                    'horsepower']),
#                                                  ('categroic_cols',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['brand', 'model',
#                                                    'fuel_type', 'transmission',
#                                                    'ext_col', 'int_col',
#                                                    'accident'])])),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=3, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=100, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %%
test_data_preds=pipe_line_2.predict(test_data_2)

# %%
submission_df_three=pd.DataFrame({
    'id':test_data['id'],
    'price':test_data_preds
})

# %%
submission_df_three.to_csv('submission_three.csv',index=False)
